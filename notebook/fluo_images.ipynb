# %%
# !pip install SimpleITK
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://packagecloud.io/github/git-lfs/pypi/simple
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
import SimpleITK as stk
import random
import os

import warnings
warnings.filterwarnings('ignore')

# %%
os.listdir()
# Out:
# ['hs_SRS_fluo_images',
#  'bbbc_broadinstitute_org',
#  'Data.md',
#  'fluorescence_microscopy.ipynb',
#  '.ipynb_checkpoints',
#  '.git',
#  'fluo_images.ipynb',
#  '44153.tif',
#  'README.md']

# %%
ROOT_DIR = "hs_SRS_fluo_images"

# %%
os.listdir(ROOT_DIR)
# Out:
# ['fixed_nuc', 'fixed_mito', 'fixed_er', 'live_mito', 'live_nuc', 'live_er']

# %% [markdown]
# ## Fixed NUC

# %%
fixed_nuc = "hs_SRS_fluo_images/fixed_nuc/"
os.listdir(fixed_nuc)
# Out:
# ['fluo', 'srs']

# %%
fluo_FN = "hs_SRS_fluo_images/fixed_nuc/fluo/"
os.listdir(fluo_FN)
# Out:
# ['A8_fluo.tif',
#  'A39_fluo.tif',
#  'A40_fluo.tif',
#  'A13_fluo.tif',
#  'A43_fluo.tif',
#  'A24_fluo.tif',
#  'A18_fluo.tif',
#  'A2_fluo.tif',
#  'A42_fluo.tif',
#  'A27_fluo.tif',
#  'A33_fluo.tif',
#  'A25_fluo.tif',
#  'A41_fluo.tif',
#  'A21_fluo.tif',
#  'A30_fluo.tif',
#  'A16_fluo.tif',
#  'A9_fluo.tif',
#  'A35_fluo.tif',
#  'A34_fluo.tif',
#  'A31_fluo.tif',
#  'A5_fluo.tif',
#  'A11_fluo.tif',
#  'A38_fluo.tif',
#  'A3_fluo.tif',
#  'A14_fluo.tif',
#  'A6_fluo.tif',
#  'A37_fluo.tif',
#  'A17_fluo.tif',
#  'A28_fluo.tif',
#  'A15_fluo.tif',
#  'A26_fluo.tif',
#  'A4_fluo.tif',
#  'A32_fluo.tif',
#  'A22_fluo.tif',
#  'A29_fluo.tif',
#  'A36_fluo.tif',
#  'A23_fluo.tif',
#  'A10_fluo.tif',
#  'A12_fluo.tif',
#  'A19_fluo.tif',
#  'A7_fluo.tif',
#  'A20_fluo.tif',
#  'A1_fluo.tif']

# %%
img = stk.ReadImage(f"{fluo_FN}/{os.listdir(fluo_FN)[0]}")
x = stk.GetArrayFromImage(img)

# %%
x.shape
# Out:
# (512, 512)

# %%
fluo_srs = "hs_SRS_fluo_images/fixed_nuc/srs/"
img = stk.ReadImage(f"{fluo_srs}/{os.listdir(fluo_srs)[0]}")
x_srs = stk.GetArrayFromImage(img)
# Out:
# TIFFReadDirectory: Warning, Unknown field with tag 50838 (0xc696) encountered.
# TIFFReadDirectory: Warning, Unknown field with tag 50839 (0xc697) encountered.
# TIFFReadDirectory: Warning, Unknown field with tag 50838 (0xc696) encountered.
# TIFFReadDirectory: Warning, Unknown field with tag 50839 (0xc697) encountered.

# %%
x_srs.shape
# Out:
# (10, 512, 512)

# %%
#plt.subplot(2,1,1)
plt.imshow(x,cmap="gray")
plt.title("Fluo")
# Out:
# Text(0.5, 1.0, 'Fluo')

# %% [markdown]
# ## Live NUC

# %%
live_FN = "hs_SRS_fluo_images/live_nuc/fluo/"
img = stk.ReadImage(f"{live_FN}/{os.listdir(live_FN)[0]}")
x = stk.GetArrayFromImage(img)
plt.imshow(x,cmap="gray")
plt.title("Fluo")
# Out:
# Text(0.5, 1.0, 'Fluo')

# %% [markdown]
# ## Fixed ER

# %%
fixed_er = "hs_SRS_fluo_images/fixed_er/fluo/"
img = stk.ReadImage(f"{fixed_er}/{os.listdir(fixed_er)[0]}")
x = stk.GetArrayFromImage(img)
plt.imshow(x,cmap="gray")
plt.title("Fluo")
# Out:
# Text(0.5, 1.0, 'Fluo')

# %% [markdown]
# ## Live ER

# %%
live_er = "hs_SRS_fluo_images/live_er/fluo/"
img = stk.ReadImage(f"{live_er}/{os.listdir(live_er)[0]}")
x = stk.GetArrayFromImage(img)
plt.imshow(x,cmap="gray")
plt.title("Fluo")
# Out:
# Text(0.5, 1.0, 'Fluo')

# %% [markdown]
# ## Fixed Mito

# %%
fix_mito = "hs_SRS_fluo_images/fixed_mito/fluo/"
img = stk.ReadImage(f"{fix_mito}/{os.listdir(fix_mito)[0]}")
x = stk.GetArrayFromImage(img)
plt.imshow(x,cmap="gray")
plt.title("fluo")
# Out:
# Text(0.5, 1.0, 'fluo')

# %% [markdown]
# ## Live Mito

# %%
live_mito = "hs_SRS_fluo_images/live_mito/fluo/"
img = stk.ReadImage(f"{live_mito}/{os.listdir(live_mito)[0]}")
x = stk.GetArrayFromImage(img)
plt.imshow(x,cmap="gray")
plt.title("fluo")
# Out:
# Text(0.5, 1.0, 'fluo')
